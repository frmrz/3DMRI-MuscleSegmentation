# %% [markdown]
# #**CONTENUTO DEL NOTEBOOK**
# In questo script confrontiamo le visualizzazioni di LDA e PCA, 2d e 3d dov'è possibile rispetto alle differenze tra le 3 condizioni muscolari. Vengono considerati i muscoli della coscia.
# > In ordine abbiamo:
# * Setting per Texture analyis
# * Estrazione delle features
# * Creazione dei Dataframes
# * features più significative
# * esclusione degli outliers (mostrare solo il 99° percentile)
# * Altre tecniche di dimensionality reduction (t-SNE, UMAP)

# %%
from google.colab import drive
drive.mount('/content/drive')
# !pip install umap-learn
# Out:
# Mounted at /content/drive
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting umap-learn
#   Downloading umap-learn-0.5.3.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 KB 1.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from umap-learn) (1.22.4)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.9/dist-packages (from umap-learn) (1.2.1)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.9/dist-packages (from umap-learn) (1.10.1)
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.9/dist-packages (from umap-learn) (0.56.4)
# Collecting pynndescent>=0.5
#   Downloading pynndescent-0.5.8.tar.gz (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 28.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from umap-learn) (4.65.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.9/dist-packages (from numba>=0.49->umap-learn) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from numba>=0.49->umap-learn) (57.4.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.9/dist-packages (from pynndescent>=0.5->umap-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.22->umap-learn) (3.1.0)
# Building wheels for collected packages: umap-learn, pynndescent
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.3-py3-none-any.whl size=82829 sha256=8f8d1066a9137e24054d2883777e9a5705dd59f4287919376986c08789a4fb66
#   Stored in directory: /root/.cache/pip/wheels/f4/3e/1c/596d0a463d17475af648688443fa4846fef624d1390339e7e9
#   Building wheel for pynndescent (setup.py) ... done
#   Created wheel for pynndescent: filename=pynndescent-0.5.8-py3-none-any.whl size=55513 sha256=858879fe7f461bb37c3552d6ebec1cdaa58921a092437ebf0b076a4525dc0793
#   Stored in directory: /root/.cache/pip/wheels/b9/89/cc/59ab91ef5b21dc2ab3635528d7d227f49dfc9169905dcb959d
# Successfully built umap-learn pynndescent
# Installing collected packages: pynndescent, umap-learn
# Successfully installed pynndescent-0.5.8 umap-learn-0.5.3

# %%
# !pip install kaleido
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting kaleido
#   Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl (79.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 12.5 MB/s eta 0:00:00
# Installing collected packages: kaleido
# Successfully installed kaleido-0.2.1

# %%
# !pip install pyradiomics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyradiomics
#   Downloading pyradiomics-3.0.1.tar.gz (34.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.5/34.5 MB 18.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.9.2 in /usr/local/lib/python3.9/dist-packages (from pyradiomics) (1.22.4)
# Collecting SimpleITK>=0.9.1
#   Downloading SimpleITK-2.2.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (52.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 MB 8.9 MB/s eta 0:00:00
# Requirement already satisfied: PyWavelets>=0.4.0 in /usr/local/lib/python3.9/dist-packages (from pyradiomics) (1.4.1)
# Collecting pykwalify>=1.6.0
#   Downloading pykwalify-1.8.0-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.9/dist-packages (from pyradiomics) (1.15.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.9/dist-packages (from pykwalify>=1.6.0->pyradiomics) (2.8.2)
# Collecting ruamel.yaml>=0.16.0
#   Downloading ruamel.yaml-0.17.21-py3-none-any.whl (109 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.5/109.5 KB 9.7 MB/s eta 0:00:00
# Collecting docopt>=0.6.2
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Collecting ruamel.yaml.clib>=0.2.6
#   Downloading ruamel.yaml.clib-0.2.7-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (519 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.4/519.4 KB 17.4 MB/s eta 0:00:00
# Building wheels for collected packages: pyradiomics, docopt
#   Building wheel for pyradiomics (setup.py) ... done
#   Created wheel for pyradiomics: filename=pyradiomics-3.0.1-cp39-cp39-linux_x86_64.whl size=185760 sha256=ff155b607cbb7e6a4ac95ab689459fe639cc73e5cc6c64a1076a60812a106a42
#   Stored in directory: /root/.cache/pip/wheels/62/0f/06/e8bdcc276fc814981e11a2fc4da7ad0da0a7e68a60fe90e747
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13723 sha256=5c8bbdf3d84dc7f113d510d1c70b51e398a7f5f91db750443f76a0f30ccabbf4
#   Stored in directory: /root/.cache/pip/wheels/70/4a/46/1309fc853b8d395e60bafaf1b6df7845bdd82c95fd59dd8d2b
# Successfully built pyradiomics docopt
# Installing collected packages: SimpleITK, docopt, ruamel.yaml.clib, ruamel.yaml, pykwalify, pyradiomics
# Successfully installed SimpleITK-2.2.1 docopt-0.6.2 pykwalify-1.8.0 pyradiomics-3.0.1 ruamel.yaml-0.17.21 ruamel.yaml.clib-0.2.7

# %% [markdown]
# #Import funzioni utili

# %%
import SimpleITK as sitk
import matplotlib.pyplot as plt
import numpy as np
from radiomics import featureextractor
from __future__ import print_function
import os
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

from glob import glob
import pandas as pd


from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from statsmodels.multivariate.manova import MANOVA
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from umap import UMAP

import plotly.express as px
import plotly.io as pio

# %% [markdown]
# #Inizializzare i parametri della texture analysis

# %%
#%%============================================================================
#             INIZIALIZZARE I PARAMETRI PER LA TEXTURE ANALYSIS
#==============================================================================

"""Sulla repository di Pyradiomics in "Example_settings" c'erano i parametri consigliati 
   per immagini MR con uno spessore di 5 mm , come quelle che compongono il nostro
   Dataset, quindi ho riportato manualmente quei settings"""

settings = {}
settings['binWidth'] = 25
settings['normalize'] = True
settings['normalizeScale'] = 100
  # Resampling:
  # Increasing the resampled spacing forces PyRadiomics to look at more coarse textures, which may or
  # may not increase accuracy and stability of your extracted features. Using a small spacing in large slices generates
  # many interpolated voxels, potentially 'masking' the signal contained in the image.
  # resampledPixelSpacing: [3, 3, 3]
settings['voxelArrayShift'] = 300

#%%============================================================================
#             INIZIALIZZARE L'EXTRACTOR SPECIFICANDO LE FEATURES
#==============================================================================
extractor = featureextractor.RadiomicsFeatureExtractor(**settings)  # ** 'unpacks' the dictionary in the function call

extractor.disableAllFeatures()
extractor.enableFeatureClassByName('firstorder')
#per via del warning : "GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated"
#disabilito SumAverage specificando tutte le altre features
extractor.enableFeaturesByName(glcm=['Autocorrelation',
    'JointAverage',
    'ClusterProminence',
    'ClusterShade',
    'ClusterTendency',
    'Contrast',
    'Correlation',
    'DifferenceAverage',
    'DifferenceEntropy',
    'DifferenceVariance',
    'JointEnergy',
    'JointEntropy',
    'Imc1',
    'Imc2',
    'Idm',
    'Idmn',
    'Id',
    'Idn',
    'InverseVariance',
    'MaximumProbability',
    'SumEntropy',
    'SumSquares'])
extractor.enableFeatureClassByName('glrlm')
extractor.enableFeatureClassByName('glszm')
extractor.enableFeatureClassByName('gldm')
print('Extraction parameters:\n\t', extractor.settings)
print('Enabled filters:\n\t', extractor.enabledImagetypes)
print('Enabled features:\n\t', extractor.enabledFeatures)
# Out:
# INFO:radiomics.featureextractor:No valid config parameter, using defaults: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': None, 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True}
# INFO:radiomics.featureextractor:Enabled image types: {'Original': {}}
# INFO:radiomics.featureextractor:Enabled features: {'firstorder': [], 'glcm': [], 'gldm': [], 'glrlm': [], 'glszm': [], 'ngtdm': [], 'shape': []}
# INFO:radiomics.featureextractor:Applying custom setting overrides: {'binWidth': 25, 'normalize': True, 'normalizeScale': 100, 'voxelArrayShift': 300}
# Extraction parameters:
# 	 {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': True, 'normalizeScale': 100, 'removeOutliers': None, 'resampledPixelSpacing': None, 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True, 'binWidth': 25, 'voxelArrayShift': 300}
# Enabled filters:
# 	 {'Original': {}}
# Enabled features:
# 	 {'firstorder': [], 'glcm': ['Autocorrelation', 'JointAverage', 'ClusterProminence', 'ClusterShade', 'ClusterTendency', 'Contrast', 'Correlation', 'DifferenceAverage', 'DifferenceEntropy', 'DifferenceVariance', 'JointEnergy', 'JointEntropy', 'Imc1', 'Imc2', 'Idm', 'Idmn', 'Id', 'Idn', 'InverseVariance', 'MaximumProbability', 'SumEntropy', 'SumSquares'], 'glrlm': [], 'glszm': [], 'gldm': []}

# %% [markdown]
# #Consideriamo ogni muscolo nelle 3 condizioni muscolari dei soggetti

# %%
directory = 'drive/MyDrive/tesi/COSCIA TA'

HV_img_path = sorted(glob(os.path.join(directory,"HV/imageshm2","*.nii")))
HV_mask_path = sorted(glob(os.path.join(directory,"HV/labels","*nii")))

FSHD_img_path = sorted(glob(os.path.join(directory,"FSHD/imageshm2","*.nii")))
FSHD_mask_path = sorted(glob(os.path.join(directory,"FSHD/labels","*.nii")))

MD1_img_path = sorted(glob(os.path.join(directory,"MD1/imageshm2","*.nii")))
MD1_mask_path = sorted(glob(os.path.join(directory,"MD1/labels","*.nii")))

df_dir = os.path.join(directory,'Dataframe')

if not os.path.exists(df_dir):
  os.mkdir(df_dir)

# %% [markdown]
# Lista di muscoli

# %%
labels = ["VL",                          # "Vasto Laterale",
          "VI",                          # "Vasto Intermedio",
          "VM",                          # "Vasto Mediale",
          "RF",                          # "Retto femorale",
          "SAR",                         # "Muscolo sartorio",
          "GRA",                         # "Muscolo gracile",
          "SEMI-MB",                     # "Muscolo semimembranoso",
          "SEMI-TN",                     # "Muscolo semitendinoso",
          "BF-CL",                       # "Bicipite femorale - capo lungo",
          "BF-CB",                       # "Bicipite femorale - capo breve",
          "ADD",                         # "Grande Adduttore + adduttore corto",
          "AL"]                          # "Adduttore Lungo"

thigh_muscles= ("Vasto Laterale",
    "Vasto Intermedio",
    "Vasto Mediale",
    "Retto femorale",
    "Muscolo sartorio",
    "Muscolo gracile",
    "Muscolo semimembranoso",
    "Muscolo semitendinoso",
    "Bicipite femorale - capo lungo",
    "Bicipite femorale - capo breve",
    "Grande Adduttore + adduttore breve",
    "Adduttore Lungo")

# thigh_muscles = ('Vastus Lateralis',
# 'Vastus Intermedius',
# 'Vastus Medialis',
# 'Rectus femoris',
# 'Sartorius', 
# 'Gracilis', 
# 'Semimembranosus', 
# 'Semitendinosus ',
# 'Biceps femoris - long head',
# 'Biceps femoris - short head',
# 'Adductor magnus + adductor brevis',
# 'Adductor Longus'
# )

# %% [markdown]
# #Estrarre le features e costruire i Dataframes
# otterremo un dataframe per ogni muscolo con la seguente struttura:
# > | 'Subject' | 'F1' | ... | 'FN' | 'Class' |

# %%
#%%============================================================================
#                             ESTRARRE LE FEATURES
#==============================================================================
exceptions = []
df_list = []     #--> è una lista di dataframe che deve contenere 12 elementi: un dataframe per ogni muscolo
for a,label in enumerate(labels):
   results = {}
   results['HV'] = {}
   results['MD1'] = {}
   results['FSHD'] = {}

   # CREARE UN DICTIONARY CHE ACCOGLIERA' I RISULTATI.
   # Poi il Dictionary sarà riarrangiato in un DataFrame per poter agevolmente applicare la tecnica di dimensionality reduction

   subject_HV = []  #mantenere questa lista torna utile per la creazione del dataframe --> iterando prendo comodamente tutti i soggetti
   for i in range(len(HV_img_path)):   #avrei potuto usare indifferentemente HV_mask_path, che ha la stessa lunghezza 
       subject_i = os.path.basename(HV_img_path[i]).split('_')[1]  #--> '001'
       subject_HV.append(subject_i)
       
   for k,j in enumerate(subject_HV):
       try:
         results['HV'][j] = extractor.execute(HV_img_path[k], HV_mask_path[k], label = a+1)  
       except:
         exception = 'label {} is not present in subject {} (HV)'.format(str(a+1),j) 
         exceptions.append(exception)
           
     

   subject_MD1 = []
   for i in range(len(MD1_img_path)):
       img_name = os.path.splitext(MD1_img_path[i])[0]
       pz = img_name.split('_')[1] #-->'001'
       num = img_name.split('_')[3]  #-->'1','2' o '3'
       subject_i = '_'.join((pz,num)) 
       subject_MD1.append(subject_i)
       
   for k,j in enumerate(subject_MD1):    
       try:
         results['MD1'][j] = extractor.execute(MD1_img_path[k], MD1_mask_path[k], label = a+1)  
       except:
         exception = 'label {} is not present in subject {} (MD1)'.format(str(a+1),j) 
         exceptions.append(exception)
           
       

   subject_FSHD = []
   for i in range(len(FSHD_img_path)):
       img_name = os.path.splitext(FSHD_img_path[i])[0]
       pz = img_name.split('_')[1] #-->'001'
       side = img_name.split('_')[4]  #-->'L' o 'R'
       subject_i = '_'.join((pz,side))
       subject_FSHD.append(subject_i)
       
   for k,j in enumerate(subject_FSHD):    
       try:
         results['FSHD'][j] = extractor.execute(FSHD_img_path[k], FSHD_mask_path[k], label = a+1)  
       except:
         exception = 'label {} is not present in subject {} (FSHD)'.format(str(a+1),j) 
         exceptions.append(exception)
           
   #%%============================================================================
   #                          COSTRUIRE IL DATAFRAME
   #==============================================================================
   """
       Dopo aver calcolato le features per tutti i pazienti selezionati
       devo organizzare i dati in una tabella o dataframe con pandas
   """

   # Delle 108 features che estraggo, solo alcume mi interessano --> feature_names (86)
   # le estraggo e le riordino 
   feature_names = list(sorted(filter ( lambda k: k.startswith("original_"), results['HV']['005'] )))

   # colonne del dataframe
   # |'Subject'|'F1'| ... |'FN'|'Class'|

   columns = ['Subject']
   for feature in feature_names:
       columns.append(feature)
   columns.append('Class')

   # riorganizzare i risultati: dal dict al df
   # costruisco riga per riga i dati che riempiranno il DataFrame

   data = []

   for subject in subject_HV:
     if subject in results['HV']:  
       row = [subject]
       for i in feature_names:
           feature = results['HV'][subject][i]
           row.append(feature)
       row.append('HV')
       data.append(row)


   for subject in subject_MD1:
     if subject in results['MD1']:
       row = [subject]
       for i in feature_names:
           feature = results['MD1'][subject][i]
           row.append(feature)
       row.append('MD1')
       data.append(row)
       
       
   for subject in subject_FSHD:
     if subject in results['FSHD']:
       row = [subject]
       for i in feature_names:
           feature = results['FSHD'][subject][i]
           row.append(feature)
       row.append('FSHD')
       data.append(row)
       
   
   
   df=pd.DataFrame(data,columns=columns) #creo il dataframe
   df.to_csv(os.path.join(df_dir,'Dataframe_{}.csv'.format(label)))
   df_list.append(df)
# Out:
# Output streaming troncato alle ultime 5000 righe.
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 7
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 7
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 7
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 7
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 7
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 7
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 7
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 7
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 7
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 7
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 7
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 7
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 7
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 7
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 7
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 7
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 7
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 7
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 7
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 7
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 7
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 7
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 8
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# ...
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 12
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 12
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 12
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 12
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 12
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 12
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 12
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 12
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 12
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 12
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 12
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 12
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 12
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 12
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 12
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 12
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 12
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 12
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 12
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 12
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 12
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 12
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 12
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 12
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 12
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 12
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 12
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 12
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 12
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm
# INFO:radiomics.featureextractor:Calculating features with label: 12
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# INFO:radiomics.featureextractor:Computing glcm
# INFO:radiomics.featureextractor:Computing glrlm
# INFO:radiomics.featureextractor:Computing glszm
# INFO:radiomics.featureextractor:Computing gldm

# %% [markdown]
# #Estrazione features mirata con test statistici

# %% [markdown]
# STEP:
# * separo le features in MD1 e FSHD. considero la stessa features (tipo Kurtosis) per i soggetti FSHD e per i soggetti MD1;
# * prima di applicare il t-test verificare le ipotesi:
# * ipotesi di normalità: test di Shapiro-Wilk
# ![image.png](data:image/png;base64,...)
#   * se la stessa features è normale in entrambi i gruppi allora la considero, altrimenti no
# * omogeneità della varianza --> test di Levene
#   * se è positivo (p-value < 0.05) --> varianza non omogenea
#   * se è negativo (p-value > 0.05) --> varianza omogenea
# * mantengo solo le features che prese singolarmente mostrano una differenza statisticamente significativa
# * pca su questo subset di features
# > LIMITE:
# a volte le features estratte solo troppo poco numerose e non si vede una buona distinzione dove invece si dovrebbe --> GRANDE ADDUTTORE. quindi guardare mann witney U test

# %%
from scipy import stats 
features_per_muscolo ={}

features_normali_per_muscolo ={}

unione_features = []

for path in df_paths:
    label = os.path.splitext(path)[0].split('_')[1]
    df = pd.read_csv(path)

    for i in range(len(feature_names)):
        print('---------------------------------------------------------------')
        print(feature_names[i])
        print(df.groupby('Class')[feature_names[i]].describe())
        
    MD1 = df[(df['Class'] == 'MD1')]
    FSHD = df[(df['Class'] == 'FSHD')]


    #omogeneità della varianza
    for i in range(len(feature_names)):
        print('---------------------------------------------------------------')
        print(feature_names[i])
        print(stats.levene(MD1[feature_names[i]], FSHD[feature_names[i]])) # ,equal_var = False##--> la varianza dei due gruppi in alcuni casi è differente
        
        
    
        
    #hanno una distribuzione normale?
    # for i in range(len(feature_names)):
    #     #plt.xlabel("Length (units)")
    #     #plt.savefig('Setosa_sepal_width')
    #     plt.figure("check", (6, 3))
    #     MD1[feature_names[i]].plot(kind="hist", title="MD1_{}".format(feature_names[i]))   
    #     plt.show()

    #     plt.figure("check", (6, 3))
    #     FSHD[feature_names[i]].plot(kind="hist", title="FSHD_{}".format(feature_names[i]), color="green")
    #     plt.show()
        
    #visivamente, la maggior parte delle distribuzioni sono normali
    #confermiamo la normalità con il test di shapiro welch
    
    features_normali = []
    for i in range(len(feature_names)):
        print('---------------------------------------------------------------')
        print(feature_names[i])
        print('MD1')
        print(stats.shapiro(MD1[feature_names[i]]))
        statistic,pvalue_md1 = stats.shapiro(MD1[feature_names[i]])
        print('FSHD')
        print(stats.shapiro(FSHD[feature_names[i]]))
        statistic,pvalue_fshd = stats.shapiro(FSHD[feature_names[i]])
        if pvalue_md1 > 0.05 and pvalue_fshd > 0.05:     #vuol dire che sono distribuzioni normali [https://pythonfordatascienceorg.wordpress.com/independent-t-test-python/]
            features_normali.append(feature_names[i])
            
    features_normali_per_muscolo[label]=features_normali   
                   


    #procediamo con il t-test vero e proprio
    #quali features sono significative per discriminare
    #il vasto intermedio in un soggetto con MD1 da quello con FSHD?

    # feature_name_interesting = []
    # for i in range(len(feature_names)):
    #     print('---------------------------------------------------------------')
    #     print(feature_names[i])
    #     print(stats.ttest_ind(MD1[feature_names[i]], FSHD[feature_names[i]],equal_var= False)) # ,equal_var = False##--> la varianza dei due gruppi in alcuni casi è differente
    #     statistics,pvalue = stats.ttest_ind(MD1[feature_names[i]], FSHD[feature_names[i]])
    #     if pvalue < 0.05:  #--> differenza significativa!
    #       feature_name_interesting.append(feature_names[i])
    #       if feature_names[i] not in unione_features:
    #           unione_features.append(feature_names[i])
          
    feature_name_interesting = []
    for i in range(len(features_normali)):
        print('---------------------------------------------------------------')
        print(features_normali[i])
        st,pv = stats.levene(MD1[features_normali[i]], FSHD[features_normali[i]])  #la varianza è omogenea? sì--> t test, no--> t-test di Wilk's (equal_var = False)
        if pv > 0.05:  #il test non è significativo significa che c'è omogeneità
            print(stats.ttest_ind(MD1[features_normali[i]], FSHD[features_normali[i]])) 
            statistics,pvalue = stats.ttest_ind(MD1[features_normali[i]], FSHD[features_normali[i]])
        else:
            print(stats.ttest_ind(MD1[features_normali[i]], FSHD[features_normali[i]],equal_var= False))
            statistics,pvalue = stats.ttest_ind(MD1[features_normali[i]], FSHD[features_normali[i]],equal_var= False)
        
        if pvalue < 0.05:  #--> differenza significativa!
          feature_name_interesting.append(features_normali[i])
          if features_normali[i] not in unione_features:
              unione_features.append(features_normali[i])
    
    features_per_muscolo[label] = feature_name_interesting
# Out:
# Output streaming troncato alle ultime 5000 righe.
# Class
# FSHD    50.0  0.060688  0.035628  0.012161  0.037345  0.051668  0.072538
# HV      10.0  0.106250  0.042205  0.027366  0.075737  0.123730  0.132298
# MD1     47.0  0.093052  0.055220  0.020657  0.053499  0.085142  0.112312
#
#             max
# Class
# FSHD   0.168336
# HV     0.168176
# MD1    0.241868
# ---------------------------------------------------------------
# original_glrlm_RunEntropy
#        count      mean       std       min       25%       50%       75%  \
# Class
# FSHD    50.0  4.138229  0.313760  3.371584  3.997206  4.178985  4.334148
# HV      10.0  3.482778  0.133189  3.179650  3.458901  3.513375  3.564962
# MD1     47.0  3.558624  0.160949  3.236337  3.468449  3.542819  3.660280
#
#             max
# Class
# FSHD   4.710852
# HV     3.627109
# MD1    4.029665
# ---------------------------------------------------------------
# original_glrlm_RunLengthNonUniformity
#        count         mean          std         min          25%          50%  \
# Class
# FSHD    50.0  2071.326651  1156.650568  508.549313  1624.896435  1883.650804
# HV      10.0  1736.367241   738.181667  562.260708  1214.653274  1623.645802
# MD1     47.0  1953.478515  1028.482189  449.099442  1150.304169  1768.824029
#
#                75%          max
# Class
# FSHD   2207.203829  5533.250256
# HV     2270.558658  2733.112965
# MD1    2858.309645  5040.815890
# ---------------------------------------------------------------
# original_glrlm_RunLengthNonUniformityNormalized
#        count      mean       std       min       25%       50%       75%  \
# Class
# FSHD    50.0  0
# original_firstorder_10Percentile
# LeveneResult(statistic=12.018905300042757, pvalue=0.0007926339204287902)
# ---------------------------------------------------------------
# original_firstorder_90Percentile
# LeveneResult(statistic=0.4720438752800082, pvalue=0.49372219608894674)
# ---------------------------------------------------------------
# original_firstorder_Energy
# LeveneResult(statistic=0.45891101796134753, pvalue=0.49977979337763945)
# ---------------------------------------------------------------
# original_firstorder_Entropy
# LeveneResult(statistic=4.673970275154318, pvalue=0.03313530590816099)
# ---------------------------------------------------------------
# original_firstorder_InterquartileRange
# LeveneResult(statistic=13.76785503231933, pvalue=0.00034838908177028396)
# ---------------------------------------------------------------
# original_firstorder_Kurtosis
# LeveneResult(statistic=0.028599319122254545, pvalue=0.8660670651119076)
# ---------------------------------------------------------------
# original_firstorder_Maximum
# LeveneResult(statistic=0.4813411867816544, pvalue=0.4895084135350318)
# ---------------------------------------------------------------
# original_firstorder_Mean
# LeveneResult(statistic=0.31019747218534127, pvalue=0.5788688214823814)
# ---------------------------------------------------------------
# original_firstorder_MeanAbsoluteDeviation
# LeveneResult(statistic=17.70481204899685, pvalue=5.848640600450326e-05)
# ---------------------------------------------------------------
# original_firstorder_Median
# LeveneResult(statistic=0.08079464475346633, pvalue=0.7768420381083041)
# ---------------------------------------------------------------
# original_firstorder_Minimum
# LeveneResult(statistic=2.036329278573429, pvalue=0.15685840885687713)
# ---------------------------------------------------------------
# original_firstorder_Range
# LeveneResult(statistic=5.291672542722329, pvalue=0.023615665842651658)
# ---------------------------------------------------------------
# original_firstorder_RobustMeanAbsoluteDeviation
# LeveneResult(statistic=20.020068108140993, pvalue=2.125965080926808e-05)
# ---------------------------------------------------------------
# original_firstorder_RootMeanSquared
# LeveneResult(statistic=0.08655764965967176, pvalue=0.7692417453654867)
# ---------------------------------------------------------------
# original_firstorder_Skewness
# LeveneResult(statistic=0.7204352121208292, pvalue=0.3981349124381274)
# ---------------------------------------------------------------
# original_firstorder_TotalEnergy
# LeveneResult(statistic=8.237143626432399, pvalue=0.005058948470285987)
# ---------------------------------------------------------------
# original_firstorder_Uniformity
# LeveneResult(statistic=0.10747263558128921, pvalue=0.7437614500612499)
# ---------------------------------------------------------------
# original_firstorder_Variance
# LeveneResult(statistic=28.187378409468725, pvalue=7.214147233771179e-07)
# ---------------------------------------------------------------
# original_glcm_Autocorrelation
# LeveneResult(statistic=0.004669972336800862, pvalue=0.9456608442269482)
# ---------------------------------------------------------------
# original_glcm_ClusterProminence
# LeveneResult(statistic=37.699964246357546, pvalue=1.905750341645522e-08)
# ---------------------------------------------------------------
# original_glcm_ClusterShade
# LeveneResult(statistic=18.25540882277476, pvalue=4.586828610403773e-05)
# ---------------------------------------------------------------
# original_glcm_ClusterTendency
# LeveneResult(statistic=44.88349510169039, pvalue=1.4713683247879125e-09)
# ---------------------------------------------------------------
# original_glcm_Contrast
# LeveneResult(statistic=12.736087181700853, pvalue=0.0005644660324255688)
# ---------------------------------------------------------------
# original_glcm_Correlation
# LeveneResult(statistic=1.6096270595311302, pvalue=0.20764415797365243)
# ---------------------------------------------------------------
# original_glcm_DifferenceAverage
# LeveneResult(statistic=10.233166221416276, pvalue=0.0018749766181131967)
# ---------------------------------------------------------------
# original_glcm_DifferenceEntropy
# LeveneResult(statistic=1.2639609636076565, pvalue=0.26373541385298244)
# ---------------------------------------------------------------
# original_glcm_DifferenceVariance
# LeveneResult(statistic=9.138445935038327, pvalue=0.0032176293629305156)
# ---------------------------------------------------------------
# original_glcm_Id
# LeveneResult(statistic=2.160271103412456, pvalue=0.14492379302522407)
# ---------------------------------------------------------------
# original_glcm_Idm
# LeveneResult(statistic=2.434359952374061, pvalue=0.12202759426935414)
# ---------------------------------------------------------------
# original_glcm_Idmn
# LeveneResult(statistic=12.156937462378377, pvalue=0.000742301648042101)
# ---------------------------------------------------------------
# original_glcm_Idn
# LeveneResult(statistic=2.4444857833840814, pvalue=0.12126371853256404)
# ---------------------------------------------------------------
# original_glcm_Imc1
# LeveneResult(statistic=39.27698404227761, pvalue=1.0725712564619355e-08)
# ---------------------------------------------------------------
# original_glcm_Imc2
# LeveneResult(statistic=0.008528286322806028, pvalue=0.9266154445106584)
# ---------------------------------------------------------------
# original_glcm_InverseVariance
# LeveneResult(statistic=1.499492585180017, pvalue=0.22377732836471842)
# ---------------------------------------------------------------
# original_glcm_JointAverage
# LeveneResult(statistic=0.6995310055985442, pvalue=0.4050402008470114)
# ---------------------------------------------------------------
# original_glcm_JointEnergy
# LeveneResult(statistic=1.7629435496576344, pvalue=0.18743937552780665)
# ---------------------------------------------------------------
# original_glcm_JointEntropy
# LeveneResult(statistic=0.11620664264696365, pvalue=0.7339384216353899)
# ---------------------------------------------------------------
# original_glcm_MaximumProbability
# LeveneResult(statistic=2.918786042708113, pvalue=0.09081920020991285)
# ---------------------------------------------------------------
# original_glcm_SumEntropy
# LeveneResult(statistic=4.509259356878455, pvalue=0.036310221385613156)
# ---------------------------------------------------------------
# original_glcm_SumSquares
# LeveneResult(statistic=28.10038793424212, pvalue=7.468529417020529e-07)
# ---------------------------------------------------------------
# original_gldm_DependenceEntropy
# LeveneResult(statistic=1.574020509969966, pvalue=0.21270199480539256)
# ---------------------------------------------------------------
# original_gldm_DependenceNonUniformity
# LeveneResult(statistic=0.3048780058015325, pvalue=0.5821370782196318)
# ---------------------------------------------------------------
# original_gldm_DependenceNonUniformityNormalized
# LeveneResult(statistic=2.0487475925089367, pvalue=0.15561304420701577)
# ---------------------------------------------------------------
# original_gldm_DependenceVariance
# LeveneResult(statistic=0.07371365072956462, pvalue=0.786593631605757)
# ---------------------------------------------------------------
# original_gldm_GrayLevelNonUniformity
# LeveneResult(statistic=0.8420498523270901, pvalue=0.3611349776192859)
# ---------------------------------------------------------------
# original_gldm_GrayLevelVariance
# LeveneResult(statistic=27.05713984494256, pvalue=1.1341520356197904e-06)
# ---------------------------------------------------------------
# original_gldm_HighGrayLevelEmphasis
# LeveneResult(statistic=0.007577562711199177, pvalue=0.930815626532563)
# ---------------------------------------------------------------
# original_gldm_LargeDependenceEmphasis
# LeveneResult(statistic=0.7874782710525631, pvalue=0.37710486559702006)
# ---------------------------------------------------------------
# original_gldm_LargeDependenceHighGrayLevelEmphasis
# LeveneResult(statistic=0.5995768689478177, pvalue=0.4406623660897785)
# ---------------------------------------------------------------
# original_gldm_LargeDependenceLowGrayLevelEmphasis
# LeveneResult(statistic=0.6484137549128903, pvalue=0.42269120720343356)
# ---------------------------------------------------------------
# original_gldm_LowGrayLevelEmphasis
# LeveneResult(statistic=3.8723932137163164, pvalue=0.052002327807635224)
# ---------------------------------------------------------------
# original_gldm_SmallDependenceEmphasis
# LeveneResult(statistic=5.6469181282118965, pvalue=0.01949230926549842)
# ---------------------------------------------------------------
# original_gldm_SmallDependenceHighGrayLevelEmphasis
# LeveneResult(statistic=1.1793228932708053, pvalue=0.28024181730440134)
# ---------------------------------------------------------------
# original_gldm_SmallDependenceLowGrayLevelEmphasis
# LeveneResult(statistic=20.53479290201069, pvalue=1.703492566609615e-05)
# ---------------------------------------------------------------
# original_glrlm_GrayLevelNonUniformity
# LeveneResult(statistic=0.0017465165709365574, pvalue=0.9667527426093055)
# ---------------------------------------------------------------
# original_glrlm_GrayLevelNonUniformityNormalized
# LeveneResult(statistic=1.2036576469331162, pvalue=0.27536501125017265)
# ---------------------------------------------------------------
# original_glrlm_GrayLevelVariance
# LeveneResult(statistic=16.291785996894486, pvalue=0.00010989735643853392)
# ---------------------------------------------------------------
# original_glrlm_HighGrayLevelRunEmphasis
# LeveneResult(statistic=0.021196542953541384, pvalue=0.8845532719243467)
# ---------------------------------------------------------------
# original_glrlm_LongRunEmphasis
# LeveneResult(statistic=15.57505085659328, pvalue=0.0001519472039292842)
# ---------------------------------------------------------------
# original_glrlm_LongRunHighGrayLevelEmphasis
# LeveneResult(statistic=1.0419580795263645, pvalue=0.3099589501060734)
# ---------------------------------------------------------------
# original_glrlm_LongRunLowGrayLevelEmphasis
# LeveneResult(statistic=5.840405875161638, pvalue=0.01757215255548413)
# ---------------------------------------------------------------
# original_glrlm_LowGrayLevelRunEmphasis
# LeveneResult(statistic=5.127077757525092, pvalue=0.025829249601041934)
# ---------------------------------------------------------------
# original_glrlm_RunEntropy
# LeveneResult(statistic=11.624157670906683, pvalue=0.0009569060397436574)
# ---------------------------------------------------------------
# original_glrlm_RunLengthNonUniformity
# LeveneResult(statistic=0.6452569044466454, pvalue=0.42381884304266304)
# ---------------------------------------------------------------
# original_glrlm_RunLengthNonUniformityNormalized
# LeveneResult(statistic=0.1339154003767791, pvalue=0.715220100808139)
# ---------------------------------------------------------------
# original_glrlm_RunPercentage
# LeveneResult(statistic=0.17498745850671799, pvalue=0.6766609284255687)
# ---------------------------------------------------------------
# original_glrlm_RunVariance
# LeveneResult(statistic=18.38652763811439, pvalue=4.329870305639002e-05)
# ---------------------------------------------------------------
# original_glrlm_ShortRunEmphasis
# LeveneResult(statistic=0.012259727084269846, pvalue=0.9120690735483884)
# ---------------------------------------------------------------
# original_glrlm_ShortRunHighGrayLevelEmphasis
# LeveneResult(statistic=0.016043424284811696, pvalue=0.899475116552464)
# ---------------------------------------------------------------
# original_glrlm_ShortRunLowGrayLevelEmphasis
# LeveneResult(statistic=4.166656038092674, pvalue=0.04400056445237928)
# ---------------------------------------------------------------
# original_glszm_GrayLevelNonUniformity
# LeveneResult(statistic=0.9592586094212818, pvalue=0.3298613688169829)
# ---------------------------------------------------------------
# original_glszm_GrayLevelNonUniformityNormalized
# LeveneResult(statistic=0.9130301777231027, pvalue=0.34173690299136295)
# ---------------------------------------------------------------
# original_glszm_GrayLevelVariance
# LeveneResult(statistic=0.20608747051822088, pvalue=0.6508868790768185)
# ---------------------------------------------------------------
# original_glszm_HighGrayLevelZoneEmphasis
# LeveneResult(statistic=1.5491854530766243, pvalue=0.21631755423244603)
# ---------------------------------------------------------------
# original_glszm_LargeAreaEmphasis
# LeveneResult(statistic=6.620197468716465, pvalue=0.011630718933360597)
# ---------------------------------------------------------------
# original_glszm_LargeAreaHighGrayLevelEmphasis
# LeveneResult(statistic=14.042644627391681, pvalue=0.000306712937450348)
# ---------------------------------------------------------------
# original_glszm_LargeAreaLowGrayLevelEmphasis
# LeveneResult(statistic=1.886188077906858, pvalue=0.1728651008465888)
# ---------------------------------------------------------------
# original_glszm_LowGrayLevelZoneEmphasis
# LeveneResult(statistic=32.50448910783023, pvalue=1.3362856960239902e-07)
# ---------------------------------------------------------------
# original_glszm_SizeZoneNonUniformity
# LeveneResult(statistic=0.002985355106235356, pvalue=0.9565412845487591)
# ---------------------------------------------------------------
# original_glszm_SizeZoneNonUniformityNormalized
# LeveneResult(statistic=3.69455747814828, pvalue=0.05758662862020367)
# ---------------------------------------------------------------
# original_glszm_SmallAreaEmphasis
# LeveneResult(statistic=4.244352064175974, pvalue=0.0421155422116921)
# ---------------------------------------------------------------
# original_glszm_SmallAreaHighGrayLevelEmphasis
# LeveneResult(statistic=2.3486269853319666, pvalue=0.12871691655252368)
# ---------------------------------------------------------------
# original_glszm_SmallAreaLowGrayLevelEmphasis
# LeveneResult(statistic=29.74170997544384, pvalue=3.901884338370372e-07)
# ---------------------------------------------------------------
# original_glszm_ZoneEntropy
# LeveneResult(statistic=0.04722723313011074, pvalue=0.8284263724812498)
# ---------------------------------------------------------------
# original_glszm_ZonePercentage
# LeveneResult(statistic=10.273270104828681, pvalue=0.0018385879746535987)
# ---------------------------------------------------------------
# original_glszm_ZoneVariance
# LeveneResult(statistic=6.1328685475140325, pvalue=0.015038052836433233)
# ---------------------------------------------------------------
# original_firstorder_10Percentile
# MD1
# ShapiroResult(statistic=0.9574465751647949, pvalue=0.08519529551267624)
# FSHD
# ShapiroResult(statistic=0.9258341193199158, pvalue=0.0038569499738514423)
# ---------------------------------------------------------------
# original_firstorder_90Percentile
# MD1
# ShapiroResult(statistic=0.9255549907684326, pvalue=0.005243027117103338)
# FSHD
# ShapiroResult(statistic=0.9758950471878052, pvalue=0.39453908801078796)
# ---------------------------------------------------------------
# original_firstorder_Energy
# MD1
# ShapiroResult(statistic=0.9025441408157349, pvalue=0.0008690601098351181)
# FSHD
# ShapiroResult(statistic=0.8653374314308167, pvalue=4.1358391172252595e-05)
# ---------------------------------------------------------------
# original_firstorder_Entropy
# MD1
# ShapiroResult(statistic=0.9513915181159973, pvalue=0.049100857228040695)
# FSHD
# ShapiroResult(statistic=0.9032773971557617, pvalue=0.0006175501621328294)
# ---------------------------------------------------------------
# original_firstorder_InterquartileRange
# MD1
# ShapiroResult(statistic=0.9779161214828491, pvalue=0.5090787410736084)
# FSHD
# ShapiroResult(statistic=0.9747684001922607, pvalue=0.3575838804244995)
# ---------------------------------------------------------------
# original_firstorder_Kurtosis
# MD1
# ShapiroResult(statistic=0.5564408302307129, pvalue=1.0645678089060695e-10)
# FSHD
# ShapiroResult(statistic=0.9296881556510925, pvalue=0.0053778463043272495)
# ---------------------------------------------------------------
# original_firstorder_Maximum
# MD1
# ShapiroResult(statistic=0.9399227499961853, pvalue=0.017700286582112312)
# FSHD
# ShapiroResult(statistic=0.9501053690910339, pvalue=0.03445671498775482)
# ---------------------------------------------------------------
# original_firstorder_Mean
# MD1
# ShapiroResult(statistic=0.9582440257072449, pvalue=0.09163487702608109)
# FSHD
# ShapiroResult(statistic=0.9453489780426025, pvalue=0.02204817347228527)
# ---------------------------------------------------------------
# original_firstorder_MeanAbsoluteDeviation
# MD1
# ShapiroResult(statistic=0.9222801923751831, pvalue=0.004014499485492706)
# FSHD
# ShapiroResult(statistic=0.9639046788215637, pvalue=0.12954460084438324)
# ---------------------------------------------------------------
# original_firstorder_Median
# MD1
# ShapiroResult(statistic=0.9519306421279907, pvalue=0.051557499915361404)
# FSHD
# ShapiroResult(statistic=0.9683989882469177, pvalue=0.19906529784202576)
# ---------------------------------------------------------------
# original_firstorder_Minimum
# MD1
# ShapiroResult(statistic=0.9023906588554382, pvalue=0.0008592111989855766)
# FSHD
# ShapiroResult(statistic=0.794804036617279, pvalue=6.669371259704349e-07)
# ---------------------------------------------------------------
# original_firstorder_Range
# MD1
# ShapiroResult(statistic=0.853031575679779, pvalue=3.106143412878737e-05)
# FSHD
# ShapiroResult(statistic=0.9427816867828369, pvalue=0.017382945865392685)
# ---------------------------------------------------------------
# original_firstorder_RobustMeanAbsoluteDeviation
# MD1
# ShapiroResult(statistic=0.9645259976387024, pvalue=0.16248035430908203)
# FSHD
# ShapiroResult(statistic=0.9766007661819458, pvalue=0.419122576713562)
# ---------------------------------------------------------------
# original_firstorder_RootMeanSquared
# MD1
# ShapiroResult(statistic=0.9575890898704529, pvalue=0.08631180226802826)
# FSHD
# ShapiroResult(statistic=0.9455687999725342, pvalue=0.02250417321920395)
# ---------------------------------------------------------------
# original_firstorder_Skewness
# MD1
# ShapiroResult(statistic=0.938659131526947, pvalue=0.01585789956152439)
# FSHD
# ShapiroResult(statistic=0.8993255496025085, pvalue=0.0004564997216220945)
# ---------------------------------------------------------------
# original_firstorder_TotalEnergy
# MD1
# ShapiroResult(statistic=0.9008464217185974, pvalue=0.0007664751610718668)
# FSHD
# ShapiroResult(statistic=0.8653373122215271, pvalue=4.1358103771926835e-05)
# ---------------------------------------------------------------
# original_firstorder_Uniformity
# MD1
# ShapiroResult(statistic=0.8957037925720215, pvalue=0.0005267877131700516)
# FSHD
# ShapiroResult(statistic=0.8876568078994751, pvalue=0.0001926693512359634)
# ---------------------------------------------------------------
# original_firstorder_Variance
# MD1
# ShapiroResult(statistic=0.7541990280151367, pvalue=1.721632258977479e-07)
# FSHD
# ShapiroResult(statistic=0.9641536474227905, pvalue=0.13268499076366425)
# ---------------------------------------------------------------
# original_glcm_Autocorrelation
# MD1
# ShapiroResult(statistic=0.6114976406097412, pvalue=6.390911688747281e-10)
# FSHD
# ShapiroResult(statistic=0.9760845303535461, pvalue=0.4010331630706787)
# ---------------------------------------------------------------
# original_glcm_ClusterProminence
# MD1
# ShapiroResult(statistic=0.38341671228408813, pvalue=8.845756158809559e-13)
# FSHD
# ShapiroResult(statistic=0.9360198378562927, pvalue=0.009404724463820457)
# ---------------------------------------------------------------
# original_glcm_ClusterShade
# MD1
# ShapiroResult(statistic=0.4784387946128845, pvalue=1.0714585468862836e-11)
# FSHD
# ShapiroResult(statistic=0.9692952036857605, pvalue=0.21663540601730347)
# ---------------------------------------------------------------
# original_glcm_ClusterTendency
# MD1
# ShapiroResult(statistic=0.7099024057388306, pvalue=2.5257424596247802e-08)
# FSHD
# ShapiroResult(statistic=0.9586833119392395, pvalue=0.07828907668590546)
# ---------------------------------------------------------------
# original_glcm_Contrast
# MD1
# ShapiroResult(statistic=0.8614841103553772, pvalue=5.249974492471665e-05)
# FSHD
# ShapiroResult(statistic=0.9138745069503784, pvalue=0.001426380593329668)
# ---------------------------------------------------------------
# original_glcm_Correlation
# MD1
# ShapiroResult(statistic=0.9526223540306091, pvalue=0.05489494279026985)
# FSHD
# ShapiroResult(statistic=0.7939713001251221, pvalue=6.385768074324005e-07)
# ---------------------------------------------------------------
# original_glcm_DifferenceAverage
# MD1
# ShapiroResult(statistic=0.9572900533676147, pvalue=0.083985835313797)
# FSHD
# ShapiroResult(statistic=0.9540359973907471, pvalue=0.05008871108293533)
# ---------------------------------------------------------------
# original_glcm_DifferenceEntropy
# MD1
# ShapiroResult(statistic=0.9850587248802185, pvalue=0.8031641244888306)
# FSHD
# ShapiroResult(statistic=0.9641572833061218, pvalue=0.1327315717935562)
# ---------------------------------------------------------------
# original_glcm_DifferenceVariance
# MD1
# ShapiroResult(statistic=0.7711902856826782, pvalue=3.8031382132430736e-07)
# FSHD
# ShapiroResult(statistic=0.9321261048316956, pvalue=0.006656604818999767)
# ---------------------------------------------------------------
# original_glcm_Id
# MD1
# ShapiroResult(statistic=0.9819328784942627, pvalue=0.6734024286270142)
# FSHD
# ShapiroResult(statistic=0.9795812368392944, pvalue=0.5344376564025879)
# ---------------------------------------------------------------
# original_glcm_Idm
# MD1
# ShapiroResult(statistic=0.9835671782493591, pvalue=0.7424083352088928)
# FSHD
# ShapiroResult(statistic=0.9776291251182556, pvalue=0.4568830132484436)
# ---------------------------------------------------------------
# original_glcm_Idmn
# MD1
# ShapiroResult(statistic=0.9805318117141724, pvalue=0.6143330335617065)
# FSHD
# ShapiroResult(statistic=0.8127593398094177, pvalue=1.7475178992754081e-06)
# ---------------------------------------------------------------
# original_glcm_Idn
# MD1
# ShapiroResult(statistic=0.9621268510818481, pvalue=0.1306406557559967)
# FSHD
# ShapiroResult(statistic=0.8880366086959839, pvalue=0.00019802286988124251)
# ---------------------------------------------------------------
# original_glcm_Imc1
# MD1
# ShapiroResult(statistic=0.9479480385780334, pvalue=0.036004047840833664)
# FSHD
# ShapiroResult(statistic=0.9142802357673645, pvalue=0.0014740239130333066)
# ---------------------------------------------------------------
# original_glcm_Imc2
# MD1
# ShapiroResult(statistic=0.9654428958892822, pvalue=0.17652983963489532)
# FSHD
# ShapiroResult(statistic=0.7451479434967041, pvalue=5.891909182764721e-08)
# ---------------------------------------------------------------
# original_glcm_InverseVariance
# MD1
# ShapiroResult(statistic=0.8887471556663513, pvalue=0.0003212393494322896)
# FSHD
# ShapiroResult(statistic=0.9393610954284668, pvalue=0.012711972929537296)
# ---------------------------------------------------------------
# original_glcm_JointAverage
# MD1
# ShapiroResult(statistic=0.78227299451828, pvalue=6.50136655622191e-07)
# FSHD
# ShapiroResult(statistic=0.9794913530349731, pvalue=0.5307149291038513)
# ---------------------------------------------------------------
# original_glcm_JointEnergy
# MD1
# ShapiroResult(statistic=0.7274265289306641, pvalue=5.271953540386676e-08)
# FSHD
# ShapiroResult(statistic=0.8588055968284607, pvalue=2.702318670344539e-05)
# ---------------------------------------------------------------
# original_glcm_JointEntropy
# MD1
# ShapiroResult(statistic=0.9551926255226135, pvalue=0.06935407221317291)
# FSHD
# ShapiroResult(statistic=0.9563795924186707, pvalue=0.0627133771777153)
# ---------------------------------------------------------------
# original_glcm_MaximumProbability
# MD1
# ShapiroResult(statistic=0.8349815607070923, pvalue=1.0653335266397335e-05)
# FSHD
# ShapiroResult(statistic=0.9226731657981873, pvalue=0.0029494138434529305)
# ---------------------------------------------------------------
# original_glcm_SumEntropy
# MD1
# ShapiroResult(statistic=0.9548537135124207, pvalue=0.06724464893341064)
# FSHD
# ShapiroResult(statistic=0.9231259226799011, pvalue=0.003064224263653159)
# ---------------------------------------------------------------
# original_glcm_SumSquares
# MD1
# ShapiroResult(statistic=0.7493095397949219, pvalue=1.3790754849196674e-07)
# FSHD
# ShapiroResult(statistic=0.9624338746070862, pvalue=0.11242656409740448)
# ---------------------------------------------------------------
# original_gldm_DependenceEntropy
# MD1
# ShapiroResult(statistic=0.9755133986473083, pvalue=0.42203488945961)
# FSHD
# ShapiroResult(statistic=0.932827889919281, pvalue=0.007081285584717989)
# ---------------------------------------------------------------
# original_gldm_DependenceNonUniformity
# MD1
# ShapiroResult(statistic=0.9458478689193726, pvalue=0.02984238974750042)
# FSHD
# ShapiroResult(statistic=0.8760250210762024, pvalue=8.49442949402146e-05)
# ---------------------------------------------------------------
# original_gldm_DependenceNonUniformityNormalized
# MD1
# ShapiroResult(statistic=0.9590626955032349, pvalue=0.09875443577766418)
# FSHD
# ShapiroResult(statistic=0.9470145106315613, pvalue=0.02575724944472313)
# ---------------------------------------------------------------
# original_gldm_DependenceVariance
# MD1
# ShapiroResult(statistic=0.8114807605743408, pvalue=2.8987064979446586e-06)
# FSHD
# ShapiroResult(statistic=0.9689239859580994, pvalue=0.20918963849544525)
# ---------------------------------------------------------------
# original_gldm_GrayLevelNonUniformity
# MD1
# ShapiroResult(statistic=0.9487290382385254, pvalue=0.03861885890364647)
# FSHD
# ShapiroResult(statistic=0.8276020884513855, pvalue=4.0368699956161436e-06)
# ---------------------------------------------------------------
# original_gldm_GrayLevelVariance
# MD1
# ShapiroResult(statistic=0.7492681741714478, pvalue=1.3765023254563857e-07)
# FSHD
# ShapiroResult(statistic=0.9624521732330322, pvalue=0.11262521147727966)
# ---------------------------------------------------------------
# original_gldm_HighGrayLevelEmphasis
# MD1
# ShapiroResult(statistic=0.6056036353111267, pvalue=5.233883326738464e-10)
# FSHD
# ShapiroResult(statistic=0.9782422184944153, pvalue=0.4804484248161316)
# ---------------------------------------------------------------
# original_gldm_LargeDependenceEmphasis
# MD1
# ShapiroResult(statistic=0.8837407231330872, pvalue=0.00022698106477037072)
# FSHD
# ShapiroResult(statistic=0.9675110578536987, pvalue=0.1829817146062851)
# ---------------------------------------------------------------
# original_gldm_LargeDependenceHighGrayLevelEmphasis
# MD1
# ShapiroResult(statistic=0.38874387741088867, pvalue=1.0097677902165536e-12)
# FSHD
# ShapiroResult(statistic=0.9598562717437744, pvalue=0.08766848593950272)
# ---------------------------------------------------------------
# original_gldm_LargeDependenceLowGrayLevelEmphasis
# MD1
# ShapiroResult(statistic=0.795632004737854, pvalue=1.2682863825830282e-06)
# FSHD
# ShapiroResult(statistic=0.7404512166976929, pvalue=4.757168525770794e-08)
# ---------------------------------------------------------------
# original_gldm_LowGrayLevelEmphasis
# MD1
# ShapiroResult(statistic=0.8664602041244507, pvalue=7.205675501609221e-05)
# FSHD
# ShapiroResult(statistic=0.869413435459137, pvalue=5.423030597739853e-05)
# ---------------------------------------------------------------
# original_gldm_SmallDependenceEmphasis
# MD1
# ShapiroResult(statistic=0.8743176460266113, pvalue=0.00012026072363369167)
# FSHD
# ShapiroResult(statistic=0.9047412276268005, pvalue=0.0006916223792359233)
# ---------------------------------------------------------------
# original_gldm_SmallDependenceHighGrayLevelEmphasis
# MD1
# ShapiroResult(statistic=0.5669039487838745, pvalue=1.4786467883443066e-10)
# FSHD
# ShapiroResult(statistic=0.9528970122337341, pvalue=0.04492437466979027)
# ---------------------------------------------------------------
# original_gldm_SmallDependenceLowGrayLevelEmphasis
# MD1
# ShapiroResult(statistic=0.8795838952064514, pvalue=0.0001710136712063104)
# FSHD
# ShapiroResult(statistic=0.8910998106002808, pvalue=0.0002474099164828658)
# ---------------------------------------------------------------
# original_glrlm_GrayLevelNonUniformity
# MD1
# ShapiroResult(statistic=0.9366738796234131, pvalue=0.013357582502067089)
# FSHD
# ShapiroResult(statistic=0.808350682258606, pvalue=1.3728216572417296e-06)
# ---------------------------------------------------------------
# original_glrlm_GrayLevelNonUniformityNormalized
# MD1
# ShapiroResult(statistic=0.9593220949172974, pvalue=0.1011241227388382)
# FSHD
# ShapiroResult(statistic=0.8783336281776428, pvalue=9.963149932445958e-05)
# ---------------------------------------------------------------
# original_glrlm_GrayLevelVariance
# MD1
# ShapiroResult(statistic=0.697084903717041, pvalue=1.5006868636646686e-08)
# FSHD
# ShapiroResult(statistic=0.953252911567688, pvalue=0.046476516872644424)
# ---------------------------------------------------------------
# original_glrlm_HighGrayLevelRunEmphasis
# MD1
# ShapiroResult(statistic=0.616962730884552, pvalue=7.705075466546418e-10)
# FSHD
# ShapiroResult(statistic=0.9858863353729248, pvalue=0.808951735496521)
# ---------------------------------------------------------------
# original_glrlm_LongRunEmphasis
# MD1
# ShapiroResult(statistic=0.7458946108818054, pvalue=1.1829666135554362e-07)
# FSHD
# ShapiroResult(statistic=0.9413198232650757, pvalue=0.0151986014097929)
# ---------------------------------------------------------------
# original_glrlm_LongRunHighGrayLevelEmphasis
# MD1
# ShapiroResult(statistic=0.39731645584106445, pvalue=1.2516387665889583e-12)
# FSHD
# ShapiroResult(statistic=0.9475212097167969, pvalue=0.027010083198547363)
# ---------------------------------------------------------------
# original_glrlm_LongRunLowGrayLevelEmphasis
# MD1
# ShapiroResult(statistic=0.8509773015975952, pvalue=2.7406815206632018e-05)
# FSHD
# ShapiroResult(statistic=0.7727167010307312, pvalue=2.1784792636481143e-07)
# ---------------------------------------------------------------
# original_glrlm_LowGrayLevelRunEmphasis
# MD1
# ShapiroResult(statistic=0.8965350985527039, pvalue=0.0005594004178419709)
# FSHD
# ShapiroResult(statistic=0.8912584185600281, pvalue=0.0002502980059944093)
# ---------------------------------------------------------------
# original_glrlm_RunEntropy
# MD1
# ShapiroResult(statistic=0.9532421827316284, pvalue=0.0580732487142086)
# FSHD
# ShapiroResult(statistic=0.944557785987854, pvalue=0.020485328510403633)
# ---------------------------------------------------------------
# original_glrlm_RunLengthNonUniformity
# MD1
# ShapiroResult(statistic=0.9423038959503174, pvalue=0.021805310621857643)
# FSHD
# ShapiroResult(statistic=0.8326650857925415, pvalue=5.421278274297947e-06)
# ---------------------------------------------------------------
# original_glrlm_RunLengthNonUniformityNormalized
# MD1
# ShapiroResult(statistic=0.9784831404685974, pvalue=0.531097412109375)
# FSHD
# ShapiroResult(statistic=0.9895360469818115, pvalue=0.9347493648529053)
# ---------------------------------------------------------------
# original_glrlm_RunPercentage
# MD1
# ShapiroResult(statistic=0.9648289680480957, pvalue=0.1669999659061432)
# FSHD
# ShapiroResult(statistic=0.9838095903396606, pvalue=0.7194728851318359)
# ---------------------------------------------------------------
# original_glrlm_RunVariance
# MD1
# ShapiroResult(statistic=0.6590744256973267, pvalue=3.466547937591713e-09)
# FSHD
# ShapiroResult(statistic=0.9209596514701843, pvalue=0.0025543910451233387)
# ---------------------------------------------------------------
# original_glrlm_ShortRunEmphasis
# MD1
# ShapiroResult(statistic=0.9835831522941589, pvalue=0.7430760860443115)
# FSHD
# ShapiroResult(statistic=0.9864957332611084, pvalue=0.8335184454917908)
# ---------------------------------------------------------------
# original_glrlm_ShortRunHighGrayLevelEmphasis
# MD1
# ShapiroResult(statistic=0.639521598815918, pvalue=1.6998281671121163e-09)
# FSHD
# ShapiroResult(statistic=0.9881349205970764, pvalue=0.8932765126228333)
# ---------------------------------------------------------------
# original_glrlm_ShortRunLowGrayLevelEmphasis
# MD1
# ShapiroResult(statistic=0.9091318249702454, pvalue=0.0014273843262344599)
# FSHD
# ShapiroResult(statistic=0.8600193858146667, pvalue=2.922412932093721e-05)
# ---------------------------------------------------------------
# original_glszm_GrayLevelNonUniformity
# MD1
# ShapiroResult(statistic=0.8996164202690125, pvalue=0.0007001981721259654)
# FSHD
# ShapiroResult(statistic=0.860704779624939, pvalue=3.0550094379577786e-05)
# ---------------------------------------------------------------
# original_glszm_GrayLevelNonUniformityNormalized
# MD1
# ShapiroResult(statistic=0.9245488047599792, pvalue=0.004828148055821657)
# FSHD
# ShapiroResult(statistic=0.9378461837768555, pvalue=0.011082642711699009)
# ---------------------------------------------------------------
# original_glszm_GrayLevelVariance
# MD1
# ShapiroResult(statistic=0.602249026298523, pvalue=4.67564986728064e-10)
# FSHD
# ShapiroResult(statistic=0.9437469244003296, pvalue=0.01900295726954937)
# ...
# FSHD
# ShapiroResult(statistic=0.9861278533935547, pvalue=0.8188115358352661)
# ---------------------------------------------------------------
# original_glcm_JointEnergy
# MD1
# ShapiroResult(statistic=0.7931749820709229, pvalue=1.6891503946681041e-06)
# FSHD
# ShapiroResult(statistic=0.7289671301841736, pvalue=2.8479229641220627e-08)
# ---------------------------------------------------------------
# original_glcm_JointEntropy
# MD1
# ShapiroResult(statistic=0.9786273241043091, pvalue=0.5651552677154541)
# FSHD
# ShapiroResult(statistic=0.9380690455436707, pvalue=0.011307903565466404)
# ---------------------------------------------------------------
# original_glcm_MaximumProbability
# MD1
# ShapiroResult(statistic=0.8748326301574707, pvalue=0.00017049700545612723)
# FSHD
# ShapiroResult(statistic=0.8931379914283752, pvalue=0.0002873808844015002)
# ---------------------------------------------------------------
# original_glcm_SumEntropy
# MD1
# ShapiroResult(statistic=0.9760523438453674, pvalue=0.46929627656936646)
# FSHD
# ShapiroResult(statistic=0.9127630591392517, pvalue=0.0013040080666542053)
# ---------------------------------------------------------------
# original_glcm_SumSquares
# MD1
# ShapiroResult(statistic=0.9666802883148193, pvalue=0.21857397258281708)
# FSHD
# ShapiroResult(statistic=0.8399710059165955, pvalue=8.370269824808929e-06)
# ---------------------------------------------------------------
# original_gldm_DependenceEntropy
# MD1
# ShapiroResult(statistic=0.9510989785194397, pvalue=0.055905453860759735)
# FSHD
# ShapiroResult(statistic=0.9345125555992126, pvalue=0.008221184834837914)
# ---------------------------------------------------------------
# original_gldm_DependenceNonUniformity
# MD1
# ShapiroResult(statistic=0.9404658079147339, pvalue=0.02236987091600895)
# FSHD
# ShapiroResult(statistic=0.957209587097168, pvalue=0.06792598217725754)
# ---------------------------------------------------------------
# original_gldm_DependenceNonUniformityNormalized
# MD1
# ShapiroResult(statistic=0.8994090557098389, pvalue=0.0009082017932087183)
# FSHD
# ShapiroResult(statistic=0.8396157026290894, pvalue=8.19326851342339e-06)
# ---------------------------------------------------------------
# original_gldm_DependenceVariance
# MD1
# ShapiroResult(statistic=0.8976341485977173, pvalue=0.0008003331022337079)
# FSHD
# ShapiroResult(statistic=0.9737833738327026, pvalue=0.3275822103023529)
# ---------------------------------------------------------------
# original_gldm_GrayLevelNonUniformity
# MD1
# ShapiroResult(statistic=0.9423443675041199, pvalue=0.026242142543196678)
# FSHD
# ShapiroResult(statistic=0.9519000053405762, pvalue=0.04085347801446915)
# ---------------------------------------------------------------
# original_gldm_GrayLevelVariance
# MD1
# ShapiroResult(statistic=0.9167226552963257, pvalue=0.003279905067756772)
# FSHD
# ShapiroResult(statistic=0.8406670689582825, pvalue=8.728827197046485e-06)
# ---------------------------------------------------------------
# original_gldm_HighGrayLevelEmphasis
# MD1
# ShapiroResult(statistic=0.5119994878768921, pvalue=5.041176504017031e-11)
# FSHD
# ShapiroResult(statistic=0.9746775031089783, pvalue=0.3547256588935852)
# ---------------------------------------------------------------
# original_gldm_LargeDependenceEmphasis
# MD1
# ShapiroResult(statistic=0.9409679770469666, pvalue=0.023342834785580635)
# FSHD
# ShapiroResult(statistic=0.9702577590942383, pvalue=0.23709359765052795)
# ---------------------------------------------------------------
# original_gldm_LargeDependenceHighGrayLevelEmphasis
# MD1
# ShapiroResult(statistic=0.4540693163871765, pvalue=1.0177754472540101e-11)
# FSHD
# ShapiroResult(statistic=0.9038745760917664, pvalue=0.0006467017228715122)
# ---------------------------------------------------------------
# original_gldm_LargeDependenceLowGrayLevelEmphasis
# MD1
# ShapiroResult(statistic=0.8489617109298706, pvalue=3.4432792745064944e-05)
# FSHD
# ShapiroResult(statistic=0.7632722854614258, pvalue=1.3774422313872492e-07)
# ---------------------------------------------------------------
# original_gldm_LowGrayLevelEmphasis
# MD1
# ShapiroResult(statistic=0.9160122275352478, pvalue=0.0031057228334248066)
# FSHD
# ShapiroResult(statistic=0.8567452430725098, pvalue=2.36789583141217e-05)
# ---------------------------------------------------------------
# original_gldm_SmallDependenceEmphasis
# MD1
# ShapiroResult(statistic=0.8592831492424011, pvalue=6.403093721019104e-05)
# FSHD
# ShapiroResult(statistic=0.8198932409286499, pvalue=2.600516836537281e-06)
# ---------------------------------------------------------------
# original_gldm_SmallDependenceHighGrayLevelEmphasis
# MD1
# ShapiroResult(statistic=0.546452522277832, pvalue=1.390324383399033e-10)
# FSHD
# ShapiroResult(statistic=0.8638967275619507, pvalue=3.761892003240064e-05)
# ---------------------------------------------------------------
# original_gldm_SmallDependenceLowGrayLevelEmphasis
# MD1
# ShapiroResult(statistic=0.7453022003173828, pvalue=1.812858556604624e-07)
# FSHD
# ShapiroResult(statistic=0.8820598721504211, pvalue=0.00012928826618008316)
# ---------------------------------------------------------------
# original_glrlm_GrayLevelNonUniformity
# MD1
# ShapiroResult(statistic=0.9338018894195557, pvalue=0.01280883327126503)
# FSHD
# ShapiroResult(statistic=0.9651534557342529, pvalue=0.14606516063213348)
# ---------------------------------------------------------------
# original_glrlm_GrayLevelNonUniformityNormalized
# MD1
# ShapiroResult(statistic=0.9475146532058716, pvalue=0.04092789813876152)
# FSHD
# ShapiroResult(statistic=0.790569007396698, pvalue=5.352747507458844e-07)
# ---------------------------------------------------------------
# original_glrlm_GrayLevelVariance
# MD1
# ShapiroResult(statistic=0.8209615349769592, pvalue=7.10458516550716e-06)
# FSHD
# ShapiroResult(statistic=0.8142879009246826, pvalue=1.9014725012311828e-06)
# ---------------------------------------------------------------
# original_glrlm_HighGrayLevelRunEmphasis
# MD1
# ShapiroResult(statistic=0.5155746936798096, pvalue=5.587836096609955e-11)
# FSHD
# ShapiroResult(statistic=0.9660729765892029, pvalue=0.15952087938785553)
# ---------------------------------------------------------------
# original_glrlm_LongRunEmphasis
# MD1
# ShapiroResult(statistic=0.9172252416610718, pvalue=0.00340933701954782)
# FSHD
# ShapiroResult(statistic=0.8478631973266602, pvalue=1.3548365132010076e-05)
# ---------------------------------------------------------------
# original_glrlm_LongRunHighGrayLevelEmphasis
# MD1
# ShapiroResult(statistic=0.4601778984069824, pvalue=1.1979551031715552e-11)
# FSHD
# ShapiroResult(statistic=0.8052743077278137, pvalue=1.162267381005222e-06)
# ---------------------------------------------------------------
# original_glrlm_LongRunLowGrayLevelEmphasis
# MD1
# ShapiroResult(statistic=0.9389057755470276, pvalue=0.019607987254858017)
# FSHD
# ShapiroResult(statistic=0.703696608543396, pvalue=9.647490806230508e-09)
# ---------------------------------------------------------------
# original_glrlm_LowGrayLevelRunEmphasis
# MD1
# ShapiroResult(statistic=0.9336158633232117, pvalue=0.012613609433174133)
# FSHD
# ShapiroResult(statistic=0.8554147481918335, pvalue=2.17542183236219e-05)
# ---------------------------------------------------------------
# original_glrlm_RunEntropy
# MD1
# ShapiroResult(statistic=0.9438215494155884, pvalue=0.029773470014333725)
# FSHD
# ShapiroResult(statistic=0.9151971936225891, pvalue=0.0015880076680332422)
# ---------------------------------------------------------------
# original_glrlm_RunLengthNonUniformity
# MD1
# ShapiroResult(statistic=0.9471290707588196, pvalue=0.03958415240049362)
# FSHD
# ShapiroResult(statistic=0.9489530324935913, pvalue=0.030903346836566925)
# ---------------------------------------------------------------
# original_glrlm_RunLengthNonUniformityNormalized
# MD1
# ShapiroResult(statistic=0.975528359413147, pvalue=0.45108702778816223)
# FSHD
# ShapiroResult(statistic=0.9675478935241699, pvalue=0.18362365663051605)
# ---------------------------------------------------------------
# original_glrlm_RunPercentage
# MD1
# ShapiroResult(statistic=0.9742404222488403, pvalue=0.40841811895370483)
# FSHD
# ShapiroResult(statistic=0.9838133454322815, pvalue=0.7196397185325623)
# ---------------------------------------------------------------
# original_glrlm_RunVariance
# MD1
# ShapiroResult(statistic=0.8938271999359131, pvalue=0.0006121161859482527)
# FSHD
# ShapiroResult(statistic=0.8059898614883423, pvalue=1.2079925681973691e-06)
# ---------------------------------------------------------------
# original_glrlm_ShortRunEmphasis
# MD1
# ShapiroResult(statistic=0.9822615385055542, pvalue=0.7119368314743042)
# FSHD
# ShapiroResult(statistic=0.9842413663864136, pvalue=0.738563597202301)
# ---------------------------------------------------------------
# original_glrlm_ShortRunHighGrayLevelEmphasis
# MD1
# ShapiroResult(statistic=0.535031795501709, pvalue=9.87669876439945e-11)
# FSHD
# ShapiroResult(statistic=0.9836471676826477, pvalue=0.7122566103935242)
# ---------------------------------------------------------------
# original_glrlm_ShortRunLowGrayLevelEmphasis
# MD1
# ShapiroResult(statistic=0.9385776519775391, pvalue=0.019073763862252235)
# FSHD
# ShapiroResult(statistic=0.9142011404037476, pvalue=0.001464609638787806)
# ---------------------------------------------------------------
# original_glszm_GrayLevelNonUniformity
# MD1
# ShapiroResult(statistic=0.9585348963737488, pvalue=0.1073903739452362)
# FSHD
# ShapiroResult(statistic=0.97579026222229, pvalue=0.3909832537174225)
# ---------------------------------------------------------------
# original_glszm_GrayLevelNonUniformityNormalized
# MD1
# ShapiroResult(statistic=0.9129818081855774, pvalue=0.0024653493892401457)
# FSHD
# ShapiroResult(statistic=0.9321367740631104, pvalue=0.0066628423519432545)
# ---------------------------------------------------------------
# original_glszm_GrayLevelVariance
# MD1
# ShapiroResult(statistic=0.789522111415863, pvalue=1.4102756722422782e-06)
# FSHD
# ShapiroResult(statistic=0.9651256799697876, pvalue=0.1456768810749054)
# ---------------------------------------------------------------
# original_glszm_HighGrayLevelZoneEmphasis
# MD1
# ShapiroResult(statistic=0.5966025590896606, pvalue=6.713661848678498e-10)
# FSHD
# ShapiroResult(statistic=0.9004679322242737, pvalue=0.0004979001241736114)
# ---------------------------------------------------------------
# original_glszm_LargeAreaEmphasis
# MD1
# ShapiroResult(statistic=0.8834377527236938, pvalue=0.00030064568272791803)
# FSHD
# ShapiroResult(statistic=0.9091022610664368, pvalue=0.0009735458879731596)
# ---------------------------------------------------------------
# original_glszm_LargeAreaHighGrayLevelEmphasis
# MD1
# ShapiroResult(statistic=0.8589614629745483, pvalue=6.278317596297711e-05)
# FSHD
# ShapiroResult(statistic=0.7698267698287964, pvalue=1.8910773746938503e-07)
# ---------------------------------------------------------------
# original_glszm_LargeAreaLowGrayLevelEmphasis
# MD1
# ShapiroResult(statistic=0.8224054574966431, pvalue=7.680677299504168e-06)
# FSHD
# ShapiroResult(statistic=0.9339083433151245, pvalue=0.007791614159941673)
# ---------------------------------------------------------------
# original_glszm_LowGrayLevelZoneEmphasis
# MD1
# ShapiroResult(statistic=0.9428642392158508, pvalue=0.02743249200284481)
# FSHD
# ShapiroResult(statistic=0.8465306758880615, pvalue=1.2478692951845005e-05)
# ---------------------------------------------------------------
# original_glszm_SizeZoneNonUniformity
# MD1
# ShapiroResult(statistic=0.9221656918525696, pvalue=0.005009899847209454)
# FSHD
# ShapiroResult(statistic=0.9718740582466125, pvalue=0.27541449666023254)
# ---------------------------------------------------------------
# original_glszm_SizeZoneNonUniformityNormalized
# MD1
# ShapiroResult(statistic=0.9701166152954102, pvalue=0.29241764545440674)
# FSHD
# ShapiroResult(statistic=0.9855377674102783, pvalue=0.7944624423980713)
# ---------------------------------------------------------------
# original_glszm_SmallAreaEmphasis
# MD1
# ShapiroResult(statistic=0.9437866806983948, pvalue=0.029684649780392647)
# FSHD
# ShapiroResult(statistic=0.9819042682647705, pvalue=0.6345787048339844)
# ---------------------------------------------------------------
# original_glszm_SmallAreaHighGrayLevelEmphasis
# MD1
# ShapiroResult(statistic=0.6116982698440552, pvalue=1.1063626681462324e-09)
# FSHD
# ShapiroResult(statistic=0.8402265310287476, pvalue=8.500040166836698e-06)
# ---------------------------------------------------------------
# original_glszm_SmallAreaLowGrayLevelEmphasis
# MD1
# ShapiroResult(statistic=0.9199576377868652, pvalue=0.004213905427604914)
# FSHD
# ShapiroResult(statistic=0.7681236267089844, pvalue=1.7406780727924343e-07)
# ---------------------------------------------------------------
# original_glszm_ZoneEntropy
# MD1
# ShapiroResult(statistic=0.944634735584259, pvalue=0.031924691051244736)
# FSHD
# ShapiroResult(statistic=0.8894473314285278, pvalue=0.00021932917297817767)
# ---------------------------------------------------------------
# original_glszm_ZonePercentage
# MD1
# ShapiroResult(statistic=0.7582576870918274, pvalue=3.2291166007780703e-07)
# FSHD
# ShapiroResult(statistic=0.7644063234329224, pvalue=1.4545157966949773e-07)
# ---------------------------------------------------------------
# original_glszm_ZoneVariance
# MD1
# ShapiroResult(statistic=0.8837871551513672, pvalue=0.00030777466599829495)
# FSHD
# ShapiroResult(statistic=0.9103480577468872, pvalue=0.0010747642954811454)
# ---------------------------------------------------------------
# original_firstorder_10Percentile
# Ttest_indResult(statistic=-4.25733374669317, pvalue=4.9382517740730506e-05)
# ---------------------------------------------------------------
# original_firstorder_InterquartileRange
# Ttest_indResult(statistic=6.606822203456391, pvalue=2.419252865256233e-09)
# ---------------------------------------------------------------
# original_firstorder_Mean
# Ttest_indResult(statistic=-1.970352186292947, pvalue=0.051772107392038545)
# ---------------------------------------------------------------
# original_firstorder_MeanAbsoluteDeviation
# Ttest_indResult(statistic=7.32599786851967, pvalue=8.448748240655087e-11)
# ---------------------------------------------------------------
# original_firstorder_Median
# Ttest_indResult(statistic=-1.1342478018907525, pvalue=0.25960581370291547)
# ---------------------------------------------------------------
# original_firstorder_RobustMeanAbsoluteDeviation
# Ttest_indResult(statistic=7.2577189856351385, pvalue=1.1663083338459693e-10)
# ---------------------------------------------------------------
# original_firstorder_RootMeanSquared
# Ttest_indResult(statistic=-1.8511685301852827, pvalue=0.06731901967811117)
# ---------------------------------------------------------------
# original_glcm_DifferenceAverage
# Ttest_indResult(statistic=11.279867756567345, pvalue=4.1936670262251194e-19)
# ---------------------------------------------------------------
# original_glcm_DifferenceEntropy
# Ttest_indResult(statistic=12.210667408936427, pvalue=1.3795334264411948e-19)
# ---------------------------------------------------------------
# original_glcm_Id
# Ttest_indResult(statistic=-9.555194881058226, pvalue=1.15185512076517e-14)
# ---------------------------------------------------------------
# original_glcm_Idm
# Ttest_indResult(statistic=-9.987536646288925, pvalue=1.2440540099798606e-15)
# ---------------------------------------------------------------
# original_glrlm_RunLengthNonUniformityNormalized
# Ttest_indResult(statistic=10.035279677432184, pvalue=1.053828679134451e-15)
# ---------------------------------------------------------------
# original_glrlm_RunPercentage
# Ttest_indResult(statistic=9.398551554304994, pvalue=5.117301943887874e-14)
# ---------------------------------------------------------------
# original_glrlm_ShortRunEmphasis
# Ttest_indResult(statistic=9.93782100614121, pvalue=6.540585644016483e-15)
# ---------------------------------------------------------------
# original_glszm_GrayLevelNonUniformity
# Ttest_indResult(statistic=3.26767781800219, pvalue=0.0017374556044270249)
# ---------------------------------------------------------------
# original_glszm_SizeZoneNonUniformityNormalized
# Ttest_indResult(statistic=-2.621865231850183, pvalue=0.01021715119689221)

# %% [markdown]
# # Quante Principal Components?

# %%
y = np.arange(1,21)
#y = np.arange(1,6)

for path in df_paths:
  label = os.path.splitext(path)[0].split('_')[1]
  df = pd.read_csv(path)
  data_subset = df[features_per_muscolo[label]].values
  #data_subset_scaled = StandardScaler().fit_transform(data_subset)
  data_subset_scaled = MinMaxScaler().fit_transform(data_subset)

  pca = PCA(n_components = len(features_per_muscolo[label])).fit(data_subset_scaled)

  plt.plot(np.cumsum(pca.explained_variance_ratio_))
  plt.xticks(y)
  plt.title('Optimal number of PCs. Muscle: {}'.format(label))
  plt.xlabel('number of components')
  plt.ylabel('cumulative explained variance')
  plt.grid()
  plt.show()

# %% [markdown]
# #PCA con le features estratte

# %%
      
pca_results = {}

for path in df_paths:
    label = os.path.splitext(path)[0].split('_')[1]
    print(label)
    df = pd.read_csv(path)
    
    df_ridotto = df[features_per_muscolo[label]]
    
    data_subset = df_ridotto.values  
    data_subset_scaled = MinMaxScaler().fit_transform(data_subset)   #normalizzo le variabili perchè PCA risente della scala. 
  
    pca = PCA(n_components = 2)
    pca_results_2d = pca.fit_transform(data_subset_scaled)   #ottengo 3 principal components
    pca_results[label] = pca_results_2d
# Out:
# VL
# VI
# VM
# RF
# SAR
# GRA
# SEMI-MB
# SEMI-TN
# BF-CL
# BF-CB
# ADD
# AL

# %%
#%%=============================================================================
#                   FEATURES PIU' RAPPRESENTATIVE E PCA
#===============================================================================
#FEATURES PIU' RILEVANTI =! PRINCIPAL COMPONENTS

#Features rilevanti --> sono un sottoinsieme delle features di partenza e sono semplicemente quelle che pesano 
#                       maggiormente nella combinazione lineare per ottenere PCi
#Principal components --> il loro numero lo decidiamo noi e permettono di rappresentare in maniera più semplice i dati
#                         ottimizzando la combinazione delle features di partenza in modo da mantenere la maggior
#                         parte delle informazioni iniziali.

relevant_features_PC1 = {}
relevant_features_PC2 = {}


#pca_results_list = []


for path in df_paths:
  label = os.path.splitext(path)[0].split('_')[1]
  df = pd.read_csv(path)

  data_subset = df[features_per_muscolo[label]].values
  #data_subset_scaled = StandardScaler().fit_transform(data_subset)
  data_subset_scaled = MinMaxScaler().fit_transform(data_subset)   #normalizzo le variabili perchè PCA risente della scala. 
  
  pca = PCA(n_components = 2)
  pca_results_2d = pca.fit_transform(data_subset_scaled)   #ottengo 3 principal components
  #pca_results_list.append(pca_results_2d)
  #-----------------Organizzazione utile per le relevant components-------------
  pca_df = pd.DataFrame(
    data=pca_results_2d, 
    columns=['PC1', 'PC2'])
  pca_df['Class'] = df['Class']
  # Principal components correlation coefficients
  loadings = pca.components_   #coefficienti autovettori
 
  # Number of features before PCA
  n_features = pca.n_features_
 
  # PC names
  pc_list = [f'PC{i}' for i in list(range(1, n_features + 1))]
 
  # Match PC names to loadings
  pc_loadings = dict(zip(pc_list, loadings))
 
  # Dataframe con features e rispettivi pesi per ogni PC
  loadings_df = pd.DataFrame.from_dict(pc_loadings)
  loadings_df['feature_names'] = features_per_muscolo[label]
  loadings_df = loadings_df.set_index('feature_names')

  #per ogni dataframe (relativo ad un muscolo) estraggo le features più rilevanti e le metto nel dict
  #Criterio di estrazione:
  #considero il peso massimo (max(loadings_df['PCi']))
  #estraggo tutte le features associate ai pesi più elevati (ovvero maggiori di (peso_massimo - delta_piccolo))
  relevant_features_PC1[label] =  loadings_df.loc[loadings_df['PC1']>max(loadings_df['PC1'])-0.1,['PC1']]
  relevant_features_PC2[label] =  loadings_df.loc[loadings_df['PC2']>max(loadings_df['PC2'])-0.2,['PC2']]
  #relevant_features_PC3[label] =  loadings_df.loc[loadings_df['PC3']>max(loadings_df['PC3'])-0.05,['PC3']]
  #-----------------------------------------------------------------------------

  #da 86 features passo a 3 principal components. Quanta informazione perdo? --> explained_variance_ratio_
  print(label)
  print('PCA 2 components explained variance : ',pca.explained_variance_ratio_)
  print('Cumulative explained variance for 2 principal components: ',np.sum(pca.explained_variance_ratio_))
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning:
#
# Attribute `n_features_` was deprecated in version 1.2 and will be removed in 1.4. Use `n_features_in_` instead.
#
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning:
#
# Attribute `n_features_` was deprecated in version 1.2 and will be removed in 1.4. Use `n_features_in_` instead.
#
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning:
#
# Attribute `n_features_` was deprecated in version 1.2 and will be removed in 1.4. Use `n_features_in_` instead.
#
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning:
#
# Attribute `n_features_` was deprecated in version 1.2 and will be removed in 1.4. Use `n_features_in_` instead.
#
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning:
#
# Attribute `n_features_` was deprecated in version 1.2 and will be removed in 1.4. Use `n_features_in_` instead.
#
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning:
#
# Attribute `n_features_` was deprecated in version 1.2 and will be removed in 1.4. Use `n_features_in_` instead.
# VL
# PCA 2 components explained variance :  [0.63924215 0.15214015]
# Cumulative explained variance for 2 principal components:  0.7913822984786018
# VI
# PCA 2 components explained variance :  [0.52352722 0.23839219]
# Cumulative explained variance for 2 principal components:  0.7619194170978693
# VM
# PCA 2 components explained variance :  [0.62612059 0.1496919 ]
# Cumulative explained variance for 2 principal components:  0.7758124857177348
# RF
# PCA 2 components explained variance :  [0.64354803 0.16502203]
# Cumulative explained variance for 2 principal components:  0.808570067494764
# SAR
# PCA 2 components explained variance :  [0.51874786 0.20912572]
# Cumulative explained variance for 2 principal components:  0.7278735806275967
# GRA
# PCA 2 components explained variance :  [0.75323996 0.23568111]
# Cumulative explained variance for 2 principal components:  0.9889210651607476
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning:
#
# Attribute `n_features_` was deprecated in version 1.2 and will be removed in 1.4. Use `n_features_in_` instead.
#
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning:
#
# Attribute `n_features_` was deprecated in version 1.2 and will be removed in 1.4. Use `n_features_in_` instead.
#
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning:
#
# Attribute `n_features_` was deprecated in version 1.2 and will be removed in 1.4. Use `n_features_in_` instead.
#
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning:
#
# Attribute `n_features_` was deprecated in version 1.2 and will be removed in 1.4. Use `n_features_in_` instead.
#
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning:
#
# Attribute `n_features_` was deprecated in version 1.2 and will be removed in 1.4. Use `n_features_in_` instead.
# SEMI-MB
# PCA 2 components explained variance :  [0.77073678 0.1453213 ]
# Cumulative explained variance for 2 principal components:  0.9160580790294803
# SEMI-TN
# PCA 2 components explained variance :  [0.46903587 0.25097678]
# Cumulative explained variance for 2 principal components:  0.720012653234551
# BF-CL
# PCA 2 components explained variance :  [0.62737893 0.17007336]
# Cumulative explained variance for 2 principal components:  0.7974522864393023
# BF-CB
# PCA 2 components explained variance :  [0.59308851 0.24002381]
# Cumulative explained variance for 2 principal components:  0.8331123260322494
# ADD
# PCA 2 components explained variance :  [0.92020227 0.04345652]
# Cumulative explained variance for 2 principal components:  0.9636587953149118
# AL
# PCA 2 components explained variance :  [0.73079211 0.1260895 ]
# Cumulative explained variance for 2 principal components:  0.8568816047861624
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning:
#
# Attribute `n_features_` was deprecated in version 1.2 and will be removed in 1.4. Use `n_features_in_` instead.

# %%
for i,muscle in enumerate(labels):
  print(muscle)
  print(relevant_features_PC1[muscle])
  print('---------------------------------------------------')
  print('Number of most relevant features: ',relevant_features_PC1[muscle].shape[0])
# Out:
# VL
#                                                       PC1
# feature_names
# original_glcm_DifferenceAverage                  0.305543
# original_glcm_DifferenceEntropy                  0.311562
# original_glrlm_RunLengthNonUniformityNormalized  0.336704
# original_glrlm_RunPercentage                     0.361499
# original_glrlm_ShortRunEmphasis                  0.332507
# ---------------------------------------------------
# Number of most relevant features:  5
# VI
#                                                       PC1
# feature_names
# original_glcm_DifferenceEntropy                  0.257798
# original_glrlm_RunLengthNonUniformityNormalized  0.316557
# original_glrlm_RunPercentage                     0.338895
# original_glrlm_ShortRunEmphasis                  0.318764
# ---------------------------------------------------
# Number of most relevant features:  4
# VM
#                                                       PC1
# feature_names
# original_glcm_DifferenceAverage                  0.310302
# original_glcm_DifferenceEntropy                  0.329602
# original_gldm_DependenceNonUniformityNormalized  0.244528
# original_glrlm_RunLengthNonUniformityNormalized  0.332383
# original_glrlm_RunPercentage                     0.341332
# ---------------------------------------------------
# Number of most relevant features:  5
# RF
#                                                       PC1
# feature_names
# original_glcm_DifferenceAverage                  0.313560
# original_glcm_DifferenceEntropy                  0.334405
# original_glcm_JointEntropy                       0.250041
# original_glrlm_RunLengthNonUniformityNormalized  0.340283
# original_glrlm_ShortRunHighGrayLevelEmphasis     0.285380
# ---------------------------------------------------
# Number of most relevant features:  5
# SAR
#                                                       PC1
# feature_names
# original_glcm_DifferenceAverage                  0.409876
# original_gldm_DependenceNonUniformityNormalized  0.368684
# original_glrlm_RunLengthNonUniformityNormalized  0.377631
# ---------------------------------------------------
# Number of most relevant features:  3
# GRA
#                                                       PC1
# feature_names
# original_glrlm_RunLengthNonUniformityNormalized  0.462092
# original_glrlm_ShortRunEmphasis                  0.467295
# ---------------------------------------------------
# Number of most relevant features:  2
# SEMI-MB
#                         PC1
# feature_names
# original_glcm_Id   0.363638
# original_glcm_Idm  0.375249
# ---------------------------------------------------
# Number of most relevant features:  2
# SEMI-TN
#                                                       PC1
# feature_names
# original_glcm_DifferenceEntropy                  0.378884
# original_glrlm_RunLengthNonUniformityNormalized  0.352026
# ---------------------------------------------------
# Number of most relevant features:  2
# BF-CL
#                                       PC1
# feature_names
# original_glcm_DifferenceAverage  0.397442
# original_glcm_DifferenceEntropy  0.403193
# ---------------------------------------------------
# Number of most relevant features:  2
# BF-CB
#                                                       PC1
# feature_names
# original_glcm_DifferenceAverage                  0.362999
# original_glcm_DifferenceEntropy                  0.388248
# original_glrlm_RunLengthNonUniformityNormalized  0.367131
# original_glrlm_RunPercentage                     0.374775
# original_glrlm_ShortRunEmphasis                  0.365154
# ---------------------------------------------------
# Number of most relevant features:  5
# ADD
#                                                       PC1
# feature_names
# original_glcm_DifferenceEntropy                  0.295691
# original_glrlm_RunLengthNonUniformityNormalized  0.338956
# original_glrlm_RunPercentage                     0.367889
# original_glrlm_ShortRunEmphasis                  0.348860
# ---------------------------------------------------
# Number of most relevant features:  4
# AL
#                        PC1
# feature_names
# original_glcm_Id   0.32211
# original_glcm_Idm  0.33296
# ---------------------------------------------------
# Number of most relevant features:  2

# %%
for i,muscle in enumerate(labels):
  print(muscle)
  print(relevant_features_PC2[muscle])
  print('---------------------------------------------------')
  print('Number of most relevant features: ',relevant_features_PC2[muscle].shape[0])
# Out:
# VL
#                                                      PC2
# feature_names
# original_glszm_SizeZoneNonUniformityNormalized  0.309773
# original_glszm_SmallAreaEmphasis                0.298357
# ---------------------------------------------------
# Number of most relevant features:  2
# VI
#                                                          PC2
# feature_names
# original_firstorder_10Percentile                    0.259142
# original_firstorder_Kurtosis                        0.367925
# original_firstorder_Mean                            0.269469
# original_firstorder_RootMeanSquared                 0.262305
# original_firstorder_Uniformity                      0.343652
# original_glcm_MaximumProbability                    0.427643
# original_gldm_LargeDependenceHighGrayLevelEmphasis  0.283570
# ---------------------------------------------------
# Number of most relevant features:  7
# VM
#                                                       PC2
# feature_names
# original_firstorder_Mean                         0.113542
# original_firstorder_RootMeanSquared              0.118361
# original_glcm_DifferenceAverage                  0.043475
# original_glcm_DifferenceEntropy                  0.049103
# original_glcm_Idn                                0.052940
# original_gldm_DependenceNonUniformityNormalized  0.020707
# original_glrlm_RunLengthNonUniformityNormalized  0.082352
# original_glrlm_RunPercentage                     0.054401
# original_glrlm_ShortRunHighGrayLevelEmphasis     0.169843
# ---------------------------------------------------
# Number of most relevant features:  9
# RF
#                                            PC2
# feature_names
# original_firstorder_Mean              0.339611
# original_firstorder_Median            0.331195
# original_firstorder_RootMeanSquared   0.335589
# original_firstorder_TotalEnergy       0.501632
# original_gldm_GrayLevelNonUniformity  0.385513
# ---------------------------------------------------
# Number of most relevant features:  5
# SAR
#                                       PC2
# feature_names
# original_firstorder_Energy       0.602819
# original_firstorder_TotalEnergy  0.685459
# ---------------------------------------------------
# Number of most relevant features:  2
# GRA
#                                                       PC2
# feature_names
# original_glrlm_RunLengthNonUniformityNormalized  0.175944
# original_glrlm_ShortRunEmphasis                  0.171015
# ---------------------------------------------------
# Number of most relevant features:  2
# SEMI-MB
#                                              PC2
# feature_names
# original_firstorder_InterquartileRange  0.789773
# ---------------------------------------------------
# Number of most relevant features:  1
# SEMI-TN
#                                                       PC2
# feature_names
# original_glcm_Idn                                0.149334
# original_glszm_GrayLevelNonUniformityNormalized -0.048464
# ---------------------------------------------------
# Number of most relevant features:  2
# BF-CL
#                                                      PC2
# feature_names
# original_glszm_SizeZoneNonUniformityNormalized  0.694001
# original_glszm_SmallAreaEmphasis                0.689963
# ---------------------------------------------------
# Number of most relevant features:  2
# BF-CB
#                                                       PC2
# feature_names
# original_firstorder_InterquartileRange           0.606527
# original_firstorder_RobustMeanAbsoluteDeviation  0.636262
# ---------------------------------------------------
# Number of most relevant features:  2
# ADD
#                                        PC2
# feature_names
# original_glcm_MaximumProbability  0.553167
# ---------------------------------------------------
# Number of most relevant features:  1
# AL
#                                                       PC2
# feature_names
# original_firstorder_InterquartileRange           0.366687
# original_firstorder_MeanAbsoluteDeviation        0.347091
# original_firstorder_RobustMeanAbsoluteDeviation  0.360508
# original_glszm_GrayLevelNonUniformity            0.290785
# original_glszm_SizeZoneNonUniformityNormalized   0.488160
# ---------------------------------------------------
# Number of most relevant features:  5

# %% [markdown]
# #Elimino gli outliers

# %%
zoom_in_percentile_range = (0, 99)
df_plot_list = []
# for path in df_paths:
    
#     label = os.path.splitext(path)[0].split('_')[1]
#     df = pd.read_csv(path)#df mi interessa solo per la colonna delle classi
for df,label in zip (df_list,labels):
     
    X = pca_results[label]
    cutoffs_0 = np.percentile(X[:, 0], zoom_in_percentile_range)
    cutoffs_1 = np.percentile(X[:, 1], zoom_in_percentile_range)
    #cutoffs_2 = np.percentile(X[:, 2], zoom_in_percentile_range)


    no_outliers_mask = np.all(X > [cutoffs_0[0], cutoffs_1[0]], axis=1) & np.all(
            X < [cutoffs_0[1], cutoffs_1[1]], axis=1)

    pca_results_no_outliers = X[no_outliers_mask]

    #creo un dataframe con pca_results_no_outliers e le classi corrispondenti

    df_plot = pd.DataFrame(pca_results_no_outliers,columns=['pca_1','pca_2'])
    df_plot['Class'] = (df['Class'].values)[no_outliers_mask]
    df_plot_list.append(df_plot)
    #df plot segue lo stesso ordine di df_path quindi parte dal ADD

# %% [markdown]
# #VISUALIZZAZIONE

# %%
    
for df_plot,label,muscle in zip(df_plot_list,labels,thigh_muscles):
    #label = os.path.splitext(path)[0].split('_')[1]
